# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import src.utils as utils

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Load Configuration File

# %%
config_data = utils.config_load()
config_data
# Out:
# {'raw_dataset_path': 'data/raw/data.csv',
#  'data_set_path': 'data/output/data.pkl',
#  'input_set_path': 'data/output/input.pkl',
#  'output_set_path': 'data/output/output.pkl',
#  'input_columns_path': 'data/output/input_columns.pkl',
#  'train_set_path': ['data/output/X_train.pkl', 'data/output/y_train.pkl'],
#  'valid_set_path': ['data/output/X_valid.pkl', 'data/output/y_valid.pkl'],
#  'test_set_path': ['data/output/X_test.pkl', 'data/output/y_test.pkl'],
#  'index_column': 'Unnamed: 0',
#  'output_column': 'SeriousDlqin2yrs',
#  'seed': 42,
#  'test_size': 0.2,
#  'clean_late_col': 'NumberOfTimes90DaysLate',
#  'clean_late_val': 96,
#  'clean_unsecure_col': 'RevolvingUtilizationOfUnsecuredLines',
#  'constant_imputer_col': 'NumberOfDependents',
#  'constant_imputer_path': 'data/output/constant_imputer.pkl',
#  'constant_imputer_val': 0.0,
#  'median_imputer_col': 'MonthlyIncome',
#  'median_imputer_path': 'data/output/median_imputer.pkl',
#  'standardizer_path': 'data/output/standardizer.pkl',
#  'preprocessor_path': 'data/output/preprocessor.pkl',
#  'train_clean_path': ['data/output/X_train_clean.pkl',
#   'data/output/y_train_clean.pkl'],
#  'valid_clean_path': ['data/output/X_valid_clean.pkl',
#   'data/output/y_valid_clean.pkl'],
#  'test_clean_path': ['data/output/X_test_clean.pkl',
#   'data/output/y_test_clean.pkl'],
#  'list_of_model_path': 'log/list_of_model.pkl',
#  'list_of_param_path': 'log/list_of_param.pkl',
#  'list_of_tuned_model_path': 'log/list_of_tuned_model.pkl',
#  'best_model_path': 'models/best_model.pkl',
#  'best_threshold_path': 'models/best_threshold.pkl'}

# %% [markdown]
# ## Load Data

# %%
X_train = utils.pickle_load(config_data['train_set_path'][0])
y_train = utils.pickle_load(config_data['train_set_path'][1])

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
# Out:
# X_train shape: (96000, 10)
# y_train shape: (96000,)

# %%
data = pd.concat((X_train, y_train), axis=1)
data.head()
# Out:
#         RevolvingUtilizationOfUnsecuredLines  age  \
# 145776                              0.085396   60
# 61313                               0.007089   48
# 128371                              0.047499   62
# 48243                               0.050541   33
# 54026                               0.153372   50
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 145776                                     0     6.053892          500.0
# 61313                                      0     0.284185         9623.0
# 128371                                     0  6265.000000            NaN
# 48243                                      0  4821.000000            NaN
# 54026                                      0     0.375656         4000.0
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 145776                               10                        0
# 61313                                16                        0
# 128371                               19                        0
# 48243                                 9                        0
# 54026                                 9                        0
#
#         NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 145776                             2                                     0
# 61313                              2                                     0
# 128371                             4                                     0
# 48243                              3                                     0
# 54026                              1                                     0
#
#         NumberOfDependents  SeriousDlqin2yrs
# 145776                 0.0                 0
# 61313                  0.0                 0
# 128371                 0.0                 0
# 48243                  0.0                 0
# 54026                  0.0                 0

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ##### 1. Check Data Type

# %%
# Check datatype
data.dtypes
# Out:
# RevolvingUtilizationOfUnsecuredLines    float64
# age                                       int64
# NumberOfTime30-59DaysPastDueNotWorse      int64
# DebtRatio                               float64
# MonthlyIncome                           float64
# NumberOfOpenCreditLinesAndLoans           int64
# NumberOfTimes90DaysLate                   int64
# NumberRealEstateLoansOrLines              int64
# NumberOfTime60-89DaysPastDueNotWorse      int64
# NumberOfDependents                      float64
# SeriousDlqin2yrs                          int64
# dtype: object

# %% [markdown]
# ##### 2. Check Missing Value

# %%
# Check missing value
data.isna().sum()
# Out:
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           18946
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       2496
# SeriousDlqin2yrs                            0
# dtype: int64

# %%
data[data['NumberOfDependents'].isna()]
# Out:
#         RevolvingUtilizationOfUnsecuredLines  age  \
# 59728                               0.014758   69
# 135372                              0.000000   79
# 61575                               0.032305   46
# 124858                              1.000000   24
# 17288                               0.243781   51
# ...                                      ...  ...
# 142722                              1.000000   23
# 75792                               0.912596   49
# 14089                               0.013069   29
# 84180                               0.199312   61
# 55818                               0.067284   64
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 59728                                      0       21.0            NaN
# 135372                                     0        0.0            NaN
# 61575                                      0     1510.0            NaN
# 124858                                     0       66.0            NaN
# 17288                                      2      661.0            NaN
# ...                                      ...        ...            ...
# 142722                                     0        4.0            NaN
# 75792                                      0      744.0            NaN
# 14089                                      0       11.0            NaN
# 84180                                      0     3276.0            NaN
# 55818                                      0     1044.0            NaN
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 59728                                 5                        0
# 135372                                4                        0
# 61575                                 6                        0
# 124858                                0                        0
# 17288                                 2                        0
# ...                                 ...                      ...
# 142722                                1                        0
# 75792                                 7                        0
# 14089                                 3                        0
# 84180                                 3                        0
# 55818                                 3                        0
#
#         NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 59728                              0                                     0
# 135372                             0                                     0
# 61575                              2                                     0
# 124858                             0                                     0
# 17288                              1                                     0
# ...                              ...                                   ...
# 142722                             0                                     0
# 75792                              1                                     0
# 14089                              0                                     0
# 84180                              1                                     0
# 55818                              1                                     0
#
#         NumberOfDependents  SeriousDlqin2yrs
# 59728                  NaN                 0
# 135372                 NaN                 0
# 61575                  NaN                 0
# 124858                 NaN                 0
# 17288                  NaN                 0
# ...                    ...               ...
# 142722                 NaN                 0
# 75792                  NaN                 0
# 14089                  NaN                 0
# 84180                  NaN                 0
# 55818                  NaN                 0
#
# [2496 rows x 11 columns]

# %%
data[data['MonthlyIncome'].isna()]
# Out:
#         RevolvingUtilizationOfUnsecuredLines  age  \
# 128371                              0.047499   62
# 48243                               0.050541   33
# 36943                               0.044536   46
# 59728                               0.014758   69
# 6378                                0.290095   59
# ...                                      ...  ...
# 146316                              0.017290   46
# 55818                               0.067284   64
# 129006                              0.009658   83
# 87940                               0.208658   52
# 138289                              0.806880   39
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 128371                                     0     6265.0            NaN
# 48243                                      0     4821.0            NaN
# 36943                                      0     4207.0            NaN
# 59728                                      0       21.0            NaN
# 6378                                       0     4032.0            NaN
# ...                                      ...        ...            ...
# 146316                                     0     3203.0            NaN
# 55818                                      0     1044.0            NaN
# 129006                                     0       21.0            NaN
# 87940                                      0     1933.0            NaN
# 138289                                     0     1279.0            NaN
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 128371                               19                        0
# 48243                                 9                        0
# 36943                                12                        0
# 59728                                 5                        0
# 6378                                  6                        0
# ...                                 ...                      ...
# 146316                                6                        0
# 55818                                 3                        0
# 129006                               14                        0
# 87940                                 8                        0
# 138289                                9                        0
#
#         NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 128371                             4                                     0
# 48243                              3                                     0
# 36943                              4                                     0
# 59728                              0                                     0
# 6378                               2                                     0
# ...                              ...                                   ...
# 146316                             1                                     0
# 55818                              1                                     0
# 129006                             0                                     0
# 87940                              1                                     0
# 138289                             0                                     0
#
#         NumberOfDependents  SeriousDlqin2yrs
# 128371                 0.0                 0
# 48243                  0.0                 0
# 36943                  0.0                 0
# 59728                  NaN                 0
# 6378                   0.0                 0
# ...                    ...               ...
# 146316                 0.0                 0
# 55818                  NaN                 0
# 129006                 0.0                 0
# 87940                  0.0                 0
# 138289                 0.0                 0
#
# [18946 rows x 11 columns]

# %% [markdown]
# _There are two columns that have missing values, namely the <span style="background-color: #767676;">MonthlyIncome</span> and <span style="background-color: #767676;">NumberOfDependents</span> columns_
#
# ---

# %% [markdown]
# ##### 3. Data Visualization

# %%
data.columns
# Out:
# Index(['RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents', 'SeriousDlqin2yrs'],
#       dtype='object')

# %%
col = 'NumberOfTimes90DaysLate'

sns.histplot(data[col], kde=True)
plt.title(col)
# Out:
# Text(0.5, 1.0, 'NumberOfTimes90DaysLate')

# %%
data[data[col]==98]
# Out:
#         RevolvingUtilizationOfUnsecuredLines  age  \
# 42920                                    1.0   49
# 126270                                   1.0   27
# 134594                                   1.0   33
# 72671                                    1.0   23
# 40716                                    1.0   21
# ...                                      ...  ...
# 141072                                   1.0   24
# 30081                                    1.0   22
# 82424                                    1.0   22
# 98032                                    1.0   25
# 105337                                   1.0   26
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 42920                                     98        0.0         3000.0
# 126270                                    98       45.0            NaN
# 134594                                    98        0.0         4100.0
# 72671                                     98        0.0            NaN
# 40716                                     98        0.0            NaN
# ...                                      ...        ...            ...
# 141072                                    98        0.0          750.0
# 30081                                     98        0.0            NaN
# 82424                                     98        0.0            NaN
# 98032                                     98       54.0            NaN
# 105337                                    98        0.0         1550.0
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 42920                                 0                       98
# 126270                                0                       98
# 134594                                0                       98
# 72671                                 0                       98
# 40716                                 0                       98
# ...                                 ...                      ...
# 141072                                0                       98
# 30081                                 0                       98
# 82424                                 0                       98
# 98032                                 0                       98
# 105337                                0                       98
#
#         NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 42920                              0                                    98
# 126270                             0                                    98
# 134594                             0                                    98
# 72671                              0                                    98
# 40716                              0                                    98
# ...                              ...                                   ...
# 141072                             0                                    98
# 30081                              0                                    98
# 82424                              0                                    98
# 98032                              0                                    98
# 105337                             0                                    98
#
#         NumberOfDependents  SeriousDlqin2yrs
# 42920                  0.0                 0
# 126270                 0.0                 1
# 134594                 1.0                 1
# 72671                  0.0                 1
# 40716                  0.0                 0
# ...                    ...               ...
# 141072                 0.0                 0
# 30081                  NaN                 0
# 82424                  NaN                 1
# 98032                  0.0                 1
# 105337                 0.0                 1
#
# [160 rows x 11 columns]

# %%
data[data[col]==98]['NumberOfTime30-59DaysPastDueNotWorse'].value_counts()
# Out:
# 98    160
# Name: NumberOfTime30-59DaysPastDueNotWorse, dtype: int64

# %%
data[data[col]==98]['NumberOfTime60-89DaysPastDueNotWorse'].value_counts()
# Out:
# 98    160
# Name: NumberOfTime60-89DaysPastDueNotWorse, dtype: int64

# %%
data[data[col]==96]['NumberOfTime30-59DaysPastDueNotWorse'].value_counts()
# Out:
# 96    2
# Name: NumberOfTime30-59DaysPastDueNotWorse, dtype: int64

# %%
data[data[col]==96]['NumberOfTime60-89DaysPastDueNotWorse'].value_counts()
# Out:
# 96    2
# Name: NumberOfTime60-89DaysPastDueNotWorse, dtype: int64

# %% [markdown]
# _We have to drop outlier values from <span style="background-color: #767676;">NumberOfTime30-59DaysPastDueNotWorse</span>, <span style="background-color: #767676;">NumberOfTime60-89DaysPastDueNotWorse</span> and <span style="background-color: #767676;">NumberOfTimes90DaysLate</span> columns._
# _The data whose values will be dropped are **96** and **98**_
#
# ---

# %%
col = 'age'

sns.histplot(data[col], kde=True, bins=10)
plt.title(col)
# Out:
# Text(0.5, 1.0, 'age')

# %% [markdown]
# _There is no problem with age column_
#
# ---

# %%
col = 'DebtRatio'

plt.hist(data[col])
plt.title(col)
plt.show()

# %% [markdown]
# _Debt ratio = monthly debt payments by montly gross income_

# %%
data[col].describe()
# Out:
# count     96000.000000
# mean        349.352421
# std        2012.791173
# min           0.000000
# 25%           0.175350
# 50%           0.367435
# 75%           0.865646
# max      326442.000000
# Name: DebtRatio, dtype: float64

# %%
data[data[col]>10000.0]
# Out:
#         RevolvingUtilizationOfUnsecuredLines  age  \
# 35370                               0.035503   62
# 104559                              0.225789   69
# 22295                               0.158395   42
# 66786                               1.000000   63
# 91                                  0.039388   51
# ...                                      ...  ...
# 86645                               0.251780   47
# 39631                               0.000765   73
# 70864                               0.001351   27
# 76441                               0.896458   56
# 53683                               1.000000   89
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 35370                                      0    13526.0            NaN
# 104559                                     6    32843.0            NaN
# 22295                                      0    11988.0            NaN
# 66786                                      0    61907.0            NaN
# 91                                         0    15466.0            0.0
# ...                                      ...        ...            ...
# 86645                                      0    33409.0            NaN
# 39631                                      0    15893.0            NaN
# 70864                                      0    17859.0            NaN
# 76441                                      3    10218.0            NaN
# 53683                                      0    61106.5            1.0
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 35370                                26                        0
# 104559                               26                        0
# 22295                                 7                        0
# 66786                                13                        0
# 91                                    7                        0
# ...                                 ...                      ...
# 86645                                 6                        0
# 39631                                12                        0
# 70864                                17                        0
# 76441                                22                        0
# 53683                                 2                        0
#
#         NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 35370                              9                                     0
# 104559                             5                                     0
# 22295                              3                                     0
# 66786                              6                                     0
# 91                                 0                                     0
# ...                              ...                                   ...
# 86645                              2                                     0
# 39631                              7                                     0
# 70864                             11                                     0
# 76441                              5                                     0
# 53683                              0                                     0
#
#         NumberOfDependents  SeriousDlqin2yrs
# 35370                  0.0                 0
# 104559                 0.0                 1
# 22295                  4.0                 0
# 66786                  0.0                 0
# 91                     0.0                 0
# ...                    ...               ...
# 86645                  0.0                 0
# 39631                  0.0                 0
# 70864                  0.0                 0
# 76441                  0.0                 0
# 53683                  0.0                 0
#
# [115 rows x 11 columns]

# %% [markdown]
# _There is no problem with <span style="background-color: #767676;">DebtRatio</span> column_
#
# ---

# %%
col = 'MonthlyIncome'

plt.hist(data[col])
plt.title(col)
plt.show()

# %%
data[col].describe()
# Out:
# count    7.705400e+04
# mean     6.662228e+03
# std      1.519004e+04
# min      0.000000e+00
# 25%      3.400000e+03
# 50%      5.400000e+03
# 75%      8.221750e+03
# max      3.008750e+06
# Name: MonthlyIncome, dtype: float64

# %%
data[data[col]>100_000]
# Out:
#         RevolvingUtilizationOfUnsecuredLines  age  \
# 36126                               1.007832   47
# 77169                               0.195705   72
# 117818                              0.006899   48
# 119914                              0.178401   51
# 105763                              0.020142   61
# 48604                               0.277881   57
# 17440                               0.257346   72
# 73764                               0.007328   52
# 17374                               1.000000   34
# 109873                              0.948003   65
# 103284                              0.320561   43
# 37079                               0.000000   83
# 88464                               0.176144   44
# 267                                 0.007983   43
# 40814                               0.105132   50
# 134333                              1.000000   54
# 54215                               0.019980   85
# 136880                              0.471149   46
# 95271                               0.056340   44
# 142223                              0.333434   58
# 86630                               0.108568   49
# 42078                               0.025474   35
# 111366                              0.163856   44
# 46680                               0.000000   47
# 120914                              0.000000   49
# 25340                               0.017000   63
# 18842                               0.162101   65
# 90029                               0.385876   57
# 99602                               0.190132   50
# 35974                               0.439684   64
# 117421                              0.828866   35
# 118362                              0.416126   65
# 41748                               0.048699   62
# 21480                               0.955441   43
# 93565                               0.071628   50
# 40737                               0.000559   53
# 137427                              0.079804   61
# 124636                              0.036010   43
# 118170                              0.000000   50
# 119137                              0.151329   49
# 50641                               0.469025   44
# 100814                              0.027289   63
#
#         NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 36126                                      1   0.030424       141500.0
# 77169                                      0   0.000665       184903.0
# 117818                                     0   0.017707       150000.0
# 119914                                     0   0.006752       121150.0
# 105763                                     0   0.000096       166700.0
# 48604                                      1   0.185360       151855.0
# 17440                                      0   0.024297       128000.0
# 73764                                      0   0.001470      3008750.0
# 17374                                      1   0.004304       251608.0
# 109873                                     0   0.036187       101056.0
# 103284                                     0   0.092633       112000.0
# 37079                                      0   0.000000       629000.0
# 88464                                      0   0.024933       408333.0
# 267                                        1   0.009691       208333.0
# 40814                                      0   0.031744       125000.0
# 134333                                     0   0.027895       133000.0
# 54215                                      0   0.000354       166666.0
# 136880                                     0   0.109151       127400.0
# 95271                                      0   0.022389       105496.0
# 142223                                     0   0.093646       101167.0
# 86630                                      0   0.013891       119000.0
# 42078                                      0   0.014969       160000.0
# 111366                                     0   0.004013      1560100.0
# 46680                                      0   0.015478       237490.0
# 120914                                     0   0.113313       150000.0
# 25340                                      0   0.002442       218674.0
# 18842                                      0   0.043441       131350.0
# 90029                                      0   0.018196       173000.0
# 99602                                      0   0.015973       237400.0
# 35974                                      0   0.004003       582369.0
# 117421                                     0   0.017841       114344.0
# 118362                                     0   0.092043       105591.0
# 41748                                      0   0.015316       150300.0
# 21480                                      0   0.019136       125000.0
# 93565                                      0   0.008268       702500.0
# 40737                                      0   0.007993       112100.0
# 137427                                     0   0.001547       562466.0
# 124636                                     0   0.002557       428250.0
# 118170                                     0   0.008671       143000.0
# 119137                                     0   0.001313       649587.0
# 50641                                      1   0.004537      1072500.0
# 100814                                     0   0.000555       110000.0
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 36126                                 4                        3
# 77169                                 3                        0
# 117818                                8                        0
# 119914                                4                        0
# 105763                                6                        0
# 48604                                31                        0
# 17440                                18                        0
# 73764                                10                        0
# 17374                                 6                        0
# 109873                               11                        0
# 103284                               19                        0
# 37079                                 3                        0
# 88464                                 6                        0
# 267                                  11                        0
# 40814                                 7                        0
# 134333                                6                        0
# 54215                                15                        0
# 136880                               15                        0
# 95271                                19                        0
# 142223                               19                        0
# 86630                                 6                        0
# 42078                                21                        0
# 111366                               12                        0
# 46680                                 8                        0
# 120914                               10                        0
# 25340                                 3                        0
# 18842                                17                        0
# 90029                                 5                        0
# 99602                                10                        0
# 35974                                11                        0
# 117421                               11                        0
# 118362                               33                        1
# 41748                                 6                        0
# 21480                                 9                        0
# 93565                                12                        0
# 40737                                16                        0
# 137427                                7                        0
# 124636                               13                        0
# 118170                                4                        0
# 119137                                8                        0
# 50641                                 9                        0
# 100814                                7                        0
#
#         NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 36126                              1                                     1
# 77169                              0                                     0
# 117818                             0                                     0
# 119914                             0                                     0
# 105763                             0                                     0
# 48604                             13                                     0
# 17440                              2                                     0
# 73764                              1                                     0
# 17374                              1                                     0
# 109873                             0                                     0
# 103284                             4                                     0
# 37079                              0                                     0
# 88464                              2                                     0
# 267                                1                                     0
# 40814                              1                                     0
# 134333                             1                                     0
# 54215                              0                                     0
# 136880                             4                                     0
# 95271                              1                                     0
# 142223                             7                                     0
# 86630                              2                                     0
# 42078                              1                                     0
# 111366                             4                                     0
# 46680                              2                                     0
# 120914                             5                                     0
# 25340                              1                                     0
# 18842                              1                                     0
# 90029                              2                                     0
# 99602                              2                                     0
# 35974                              0                                     0
# 117421                             2                                     0
# 118362                             3                                     0
# 41748                              1                                     0
# 21480                              0                                     0
# 93565                              4                                     0
# 40737                              1                                     0
# 137427                             0                                     0
# 124636                             1                                     0
# 118170                             1                                     0
# 119137                             0                                     1
# 50641                              2                                     0
# 100814                             0                                     0
#
#         NumberOfDependents  SeriousDlqin2yrs
# 36126                  2.0                 0
# 77169                  0.0                 0
# 117818                 4.0                 0
# 119914                 2.0                 0
# 105763                 1.0                 0
# 48604                  0.0                 0
# 17440                  1.0                 0
# 73764                  3.0                 0
# 17374                  0.0                 0
# 109873                 0.0                 0
# 103284                 2.0                 0
# 37079                  0.0                 0
# 88464                  3.0                 0
# 267                    1.0                 0
# 40814                  0.0                 0
# 134333                 0.0                 0
# 54215                  0.0                 0
# 136880                 2.0                 0
# 95271                  0.0                 0
# 142223                 0.0                 1
# 86630                  0.0                 0
# 42078                  2.0                 0
# 111366                 2.0                 0
# 46680                  3.0                 0
# 120914                 3.0                 0
# 25340                  0.0                 0
# 18842                  1.0                 0
# 90029                  1.0                 0
# 99602                  3.0                 0
# 35974                  1.0                 0
# 117421                 2.0                 0
# 118362                 1.0                 0
# 41748                  0.0                 0
# 21480                  1.0                 0
# 93565                  2.0                 0
# 40737                  0.0                 0
# 137427                 1.0                 0
# 124636                 1.0                 0
# 118170                 1.0                 0
# 119137                 3.0                 0
# 50641                  1.0                 0
# 100814                 0.0                 0

# %% [markdown]
# _The difference in data is skewness, so it will be imputed using the median_
#
# ---

# %%
col = 'NumberOfDependents'

plt.hist(data[col])
plt.title(col)
plt.show()

# %% [markdown]
# _For missing values data, we assumed that they don't have dependent_
#
# ---

# %%
col = 'RevolvingUtilizationOfUnsecuredLines'

plt.hist(data[col])
plt.title(col)
plt.show()

# %%
q1, q3 = np.quantile(data[col], q=(0.25, 0.75))
iqr = q3 - q1
ub = q3 + 1.5*iqr
lb = q1 - 1.5*iqr

plt.hist(data[(data[col]>=lb) & (data[col]<= ub)][col])
# Out:
# (array([45853., 11581.,  7806.,  6022.,  4805.,  4162.,  4572., 10149.,
#           415.,   152.]),
#  array([0.        , 0.13492557, 0.26985114, 0.40477672, 0.53970229,
#         0.67462786, 0.80955343, 0.944479  , 1.07940458, 1.21433015,
#         1.34925572]),
#  <BarContainer object of 10 artists>)

# %%
ub, lb
# Out:
# (1.34977631875, -0.7618548252499999)

# %% [markdown]
# _We have to remove outlier data_
